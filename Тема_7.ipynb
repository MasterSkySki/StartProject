# %%
# Импортируем необходимые библиотеки
import pandas as pd
import seaborn as sns
import plotly.express as px
import matplotlib.pyplot as plt

# Загрузка данных из CSV-файла
csv_file_path = '/content/web_clients_correct_доп_материал_к_тема_6__7__итоговое_задание__1_ (1).csv'
df = pd.read_csv(csv_file_path)

# Проверяем первые 15 строк данных
print(df.head(15))

# Преобразование данных, если необходимо (например, обработка пропущенных значений)
df = df.dropna()  # Удаление строк с пропущенными значениями

# Создание диаграммы разброса с помощью Seaborn
plt.figure(figsize=(10, 6))
sns.scatterplot(data=df, x='age', y='bill')
plt.title('Зависимость расходов от возраста клиента')
plt.xlabel('Возраст')
plt.ylabel('Расходы')
plt.show()

# Создание диаграммы разброса с помощью Plotly
fig = px.scatter(df, x='age', y='bill')
fig.update_layout(title='Зависимость расходов от возраста клиента',
                  xaxis_title='Возраст',
                  yaxis_title='Расходы')
fig.show()
# Out:
#                                                  name device_type  \
# 0                       Allen  Miss. Elisabeth Walton      mobile
# 1                      Allison  Master. Hudson Trevor      tablet
# 2                        Allison  Miss. Helen Loraine      laptop
# 3                Allison  Mr. Hudson Joshua Creighton     desktop
# 4     Allison  Mrs. Hudson J C (Bessie Waldo Daniels)      laptop
# 5                                 Anderson  Mr. Harry      mobile
# 6                   Andrews  Miss. Kornelia Theodosia      mobile
# 7                              Andrews  Mr. Thomas Jr      tablet
# 8       Appleton  Mrs. Edward Dale (Charlotte Lamson)     desktop
# 9                             Artagaveytia  Mr. Ramon      mobile
# 10                             Astor  Col. John Jacob     desktop
# 11  Astor  Mrs. John Jacob (Madeleine Talmadge Force)      laptop
# 12                      Aubart  Mme. Leontine Pauline      tablet
# ...
